# %% [markdown]
# # Getting Started with MARA RoboSim
#
# This notebook walks through the basics of the MARA RoboSim benchmark:
# discovering available environments, creating one, taking actions,
# and rendering a video.

# %%
# %pip install mara_robosim
# Out:
# Requirement already satisfied: mara_robosim in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (0.1.0)
# Requirement already satisfied: matplotlib in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from mara_robosim) (3.6.2)
# Requirement already satisfied: numpy in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from mara_robosim) (1.23.5)
# Requirement already satisfied: pybullet in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from mara_robosim) (3.2.7)
# Requirement already satisfied: gymnasium in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from mara_robosim) (1.2.3)
# Requirement already satisfied: Pillow in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from mara_robosim) (10.3.0)
# Requirement already satisfied: scipy in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from mara_robosim) (1.9.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from gymnasium->mara_robosim) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from gymnasium->mara_robosim) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from gymnasium->mara_robosim) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from matplotlib->mara_robosim) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from matplotlib->mara_robosim) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from matplotlib->mara_robosim) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from matplotlib->mara_robosim) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from matplotlib->mara_robosim) (25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from matplotlib->mara_robosim) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from matplotlib->mara_robosim) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/yichaoliang/mambaforge/envs/pred/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mara_robosim) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib
matplotlib.use("agg")

import numpy as np
import matplotlib.pyplot as plt

import mara_robosim
from mara_robosim.config import PyBulletConfig

# %% [markdown]
# ## Discovering Available Environments
#
# MARA RoboSim provides 15 PyBullet-based robotic manipulation environments.
# Let's register them all and see what's available.

# %%
mara_robosim.register_all_environments()

env_ids = sorted(mara_robosim.get_all_env_ids())
print(f"{len(env_ids)} environments available:\n")
for eid in env_ids:
    print(f"  {eid}")
# Out:
# 15 environments available:
#
#   mara/Ants-v0
#   mara/Balance-v0
#   mara/Barrier-v0
#   mara/Blocks-v0
#   mara/Boil-v0
#   mara/Circuit-v0
#   mara/Coffee-v0
#   mara/Cover-v0
#   mara/Domino-v0
#   mara/Fan-v0
#   mara/Float-v0
#   mara/Grow-v0
#   mara/Laser-v0
#   mara/MagicBin-v0
#   mara/Switch-v0

# %% [markdown]
# ## Creating an Environment
#
# We'll use `mara/Blocks-v0`, an environment where a Fetch robot
# must stack and arrange blocks on a tabletop.

# %%
config = PyBulletConfig(camera_width=900, camera_height=900)
env = mara_robosim.make("mara/Blocks-v0", render_mode="rgb_array", config=config)
obs, info = env.reset()

frame = env.render()
if frame is not None:
    plt.imshow(frame)
    plt.axis("off")
    plt.title("mara/Blocks-v0")
    plt.show()
else:
    print("(rendering not available in this configuration)")

# %% [markdown]
# ## Exploring the Observation and Action Spaces
#
# MARA RoboSim environments follow the Gymnasium API. Observations and actions
# are continuous-valued numpy arrays.

# %%
print("Observation shape:", env.observation_space.shape)
print("Action shape:     ", env.action_space.shape)
print()

action = env.action_space.sample()
obs, reward, terminated, truncated, info = env.step(action)
print("Sample action:", np.round(action, 3))
print("Reward:       ", reward)
print("Terminated:   ", terminated)

# %% [markdown]
# ## Inspecting the Structured State
#
# Beyond the flat observation vector, the `info` dict exposes the full
# object-centric `State` and whether the goal has been reached.

# %%
state = info["state"]
print("Goal reached:", info["goal_reached"])
print()
print(state.pretty_str())

# %% [markdown]
# ## Rendering a Video
#
# Let's collect frames from random actions and display them as an animated GIF.

# %%
from io import BytesIO

from IPython.display import Image
from PIL import Image as PILImage

obs, info = env.reset()
frames = []
frame = env.render()
if frame is not None:
    frames.append(frame)

for _ in range(50):
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    frame = env.render()
    if frame is not None:
        frames.append(frame)
    if terminated or truncated:
        break

if frames:
    pil_frames = [PILImage.fromarray(f) for f in frames]
    buf = BytesIO()
    pil_frames[0].save(
        buf,
        format="GIF",
        save_all=True,
        append_images=pil_frames[1:],
        duration=100,
        loop=0,
    )
    Image(data=buf.getvalue(), format="gif")
else:
    print("(no frames captured — rendering may not be available)")

# %% [markdown]
# ## Cleanup

# %%
env.close()
